# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Documents\\shilpaaaaaa\\Swiggy DA'

# %%
items = pd.read_csv('items.csv')
orders = pd.read_csv('orders.csv')

# %%
items
# Out:
#       id      order_id                                               name  \
# 0      1  127143465064                                     Paratha Kuruma
# 1      2  127143465064                                Gobi Manchurian Dry
# 2      3  127077028490                     Amritsari Paneer Tikka Lasagne
# 3      4  126888939416                             Eggless Red Velvet Jar
# 4      5  125668909627                                           SEV PURI
# ..   ...           ...                                                ...
# 188  189    1129725726                      Triple Choco Chip Thick Shake
# 189  190    1123341565                         Cookie and Cream Milkshake
# 190  191    1123287736  Veg Pulao + 3 Phulkas + Dal Fry + Mango Drink ...
# 191  192    1096353194                 Cheese Tandoori Veg Pizza Sandwich
# 192  193    1096353194                               Mixed Choco Sandwich
#
#      is_veg
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
orders
# Out:
#     id      order_id  order_total          restaurant_name  \
# 0    1  127143465064        463.0                  A2B Veg
# 1    2  127077028490        252.0             Firangi Bake
# 2    3  126888939416        190.0                The Table
# 3    4  125668909627        258.0        Sree gupta bhavan
# 4    5  125301846779        194.0                   Idlies
# ..  ..           ...          ...                      ...
# 90  91    1161151700        313.0           Domino's Pizza
# 91  92    1129725726        192.0  The Thick Shake Factory
# 92  93    1123341565        125.0           Food Centralis
# 93  94    1123287736        209.0             Rice n Spice
# 94  95    1096353194        140.0        The Sandwich Shop
#
#              order_time  rain_mode  on_time
# 0   2022-02-05 19:07:45          0        1
# 1   2022-02-05 00:40:28          0        1
# 2   2022-02-02 20:25:40          0        1
# 3   2022-01-19 17:31:50          0        0
# ...

# %%
# unique items
items['name'].unique()
# Out:
# array(['Paratha Kuruma', 'Gobi Manchurian Dry',
#        'Amritsari Paneer Tikka Lasagne', 'Eggless Red Velvet Jar',
#        'SEV PURI', 'MASALA PURI', 'Sepangkizhangu Fries', 'Masala Kulcha',
#        'Onion Aloo Mixed Paratha', 'Mixed Vegetable Raita',
#        'Penne Arrabiata Pasta La Vista',
#        'Pind Di Daal Makhani with Jeera Rice', 'Alfredo',
#        'North Indian Value Combo Meals', 'Veg Zinger',
#        'Burnt Garlic Noodles + Chilli Corn (Serves 1)',
#        'Chicken Fried Rice + Bbq Shredded Chicken Sauce',
#        'Burnt Garlic Chicken Rice + Chilly Shredded Chicken (Serves 1)',
#        'Butter Chicken', 'Naan', 'Seven Taste Uttapam', 'Phulka',
#        'Kadai Paneer', 'Ghee Paneer Masal Dosa', 'Sambar Idli',
#        'Pomegranate Juices', 'Mango Mastani',
#        'Paneer Tikka Sub ( 15 cm, 6 Inch )',
#        'Corn & Peas Sub ( 15 cm, 6 Inch )', 'Classic Mac & Cheese',
#        'Awadhi Paneer with Matar Pulao', 'Sprite Can (300 ml)',
# ...

# %%
# no. of unique items
items['name'].nunique()
# Out:
# 164

# %%
# veg or non veg
items.groupby('is_veg')['name'].count()
# Out:
# is_veg
# 0     12
# 1    180
# 2      1
# Name: name, dtype: int64

# %%
# items contain chicken
items['ContainsChicken'] = items['name'].str.find('Chicken')

# %%
items.head(20)
# Out:
#     id      order_id                                               name  \
# 0    1  127143465064                                     Paratha Kuruma
# 1    2  127143465064                                Gobi Manchurian Dry
# 2    3  127077028490                     Amritsari Paneer Tikka Lasagne
# 3    4  126888939416                             Eggless Red Velvet Jar
# 4    5  125668909627                                           SEV PURI
# 5    6  125668909627                                        MASALA PURI
# 6    7  125301846779                               Sepangkizhangu Fries
# 7    8  124552896092                                      Masala Kulcha
# 8    9  124552896092                           Onion Aloo Mixed Paratha
# 9   10  124552896092                              Mixed Vegetable Raita
# 10  11  121958902961                     Penne Arrabiata Pasta La Vista
# 11  12  121958902961               Pind Di Daal Makhani with Jeera Rice
# ...

# %%
items[items['ContainsChicken']!=-1]
# Out:
#       id      order_id                                               name  \
# 16    17  118594611361    Chicken Fried Rice + Bbq Shredded Chicken Sauce
# 17    18  118594611361  Burnt Garlic Chicken Rice + Chilly Shredded Ch...
# 18    19  118594611361                                     Butter Chicken
# 82    83   86796819721                        Chicken Schezwan Fried Rice
# 84    85   86796243798                                     Chicken Parcel
# 85    86   86796243798                                    Chicken Sausage
# 105  106   63528835993               Peri Peri Chicken with Egg Corn Rice
# 148  149   43875533945                                 Chicken Fried Rice
# 149  150   43875533945                                     Dragon Chicken
# 170  171   20698577867                                    Crunchy Chicken
#
#      is_veg  ContainsChicken
# 16        0                0
# 17        0               13
# 18        0                7
# 82        0                0
# ...

# %%
# items orders  most of time
items_new = items.groupby('name')['id'].count().reset_index()
items_new.sort_values(by=['id'], ascending=False)
# Out:
#                                           name  id
# 46                        Classic Mac & Cheese   4
# 114     Paneer Butter Masala with Mattar Pulao   3
# 31                            Cheese corn Wrap   3
# 110                        Paneer & corn Pasta   3
# 70                             Gobi Manchurian   3
# ..                                         ...  ..
# 56              Desi Dal Tadka with Jeera Rice   1
# 57                     Double Chocolate Mousse   1
# 58                              Dragon Chicken   1
# 60   Everyday Value 2 Reg Classic Paneer Combo   1
# 163                                 Veg Zinger   1
#
# [164 rows x 2 columns]

# %%
# count of distinct order
orders['order_id'].nunique()
# Out:
# 95

# %%
# distinct restaurant name
orders['restaurant_name'].unique()
# Out:
# array(['A2B Veg', 'Firangi Bake', 'The Table', 'Sree gupta bhavan',
#        'Idlies', "Shyam's Bombay Halwa House", 'The Bowl Company',
#        'Super Munch', "Mansukh's Sweets and Snacks", 'KFC',
#        'The Chopstix- Kk Nagar', 'Sabarees Veg Restaurant', 'Lassi House',
#        'Subway', 'Faasos', "McDonald's", 'LunchBox', 'Drunken Monkey',
#        "Sangeetha's Desi Mane", 'The Sandwich Shop 2.0',
#        'The Belgian Waffle Co.', 'The Thickshake Factory',
#        "Amelie's Cafe & Creamery", 'Kamakshi Mess',
#        'Bakya Veg Restaurant', 'Roll Over', "Domino's Pizza",
#        'Moonlight Takeaway & Delivery', 'Richy Rich Ice Creams',
#        'HOTEL ANANDHA BHAVAN (Imperial Road)', 'VEJ', 'Frozen Bottle',
#        'Good For One', 'KEVENTERS', 'The Good Bowl', 'Cream and Fudge',
#        'Food Track', 'The Belgian Waffle Co', 'Oh so Stoned', 'Pizza Hut',
#        "Desi Rasoi's Punjabi Dhaba", 'Taco Bell', 'Tibbs Frankie',
# ...

# %%
# restaurant with most order rank
orders.groupby('restaurant_name')['order_id'].nunique()
# Out:
# restaurant_name
# A2B Veg                                  4
# Amelie's Cafe & Creamery                 1
# Bakya Veg Restaurant                     1
# Cream and Fudge                          2
# Desi Rasoi's Punjabi Dhaba               1
# Domino's Pizza                           4
# Drunken Monkey                           1
# Faasos                                   2
# Firangi Bake                             1
# Food Centralis                           1
# Food Track                               5
# Frozen Bottle                            2
# Good For One                             1
# HOTEL ANANDHA BHAVAN (Imperial Road)     2
# Ibaco                                    1
# Idlies                                   1
# KEVENTERS                                1
# KFC                                      1
# Kamakshi Mess                            1
# Lassi House                              1
# LunchBox                                 2
# ...

# %%
orders_new = orders.groupby('restaurant_name')['order_id'].nunique().reset_index()
orders_new.sort_values(by=['order_id'],ascending = False)
# Out:
#                          restaurant_name  order_id
# 39                      The Bowl Company        12
# 22           Mansukh's Sweets and Snacks         6
# 10                            Food Track         5
# 0                                A2B Veg         4
# 44                             The Table         4
# 5                         Domino's Pizza         4
# 31                 Sangeetha's Desi Mane         4
# 20                              LunchBox         2
# 46                The Thickshake Factory         2
# 38                The Belgian Waffle Co.         2
# 36                             Taco Bell         2
# 34                                Subway         2
# 33                     Sree gupta bhavan         2
# 32            Shyam's Bombay Halwa House         2
# 29                             Roll Over         2
# 23                            McDonald's         2
# 24         Moonlight Takeaway & Delivery         2
# ...

# %%
# rank
orders_new['Rank']=orders_new['order_id'].rank(method='first', ascending = False)

# %%
orders_new
# Out:
#                          restaurant_name  order_id  Rank
# 0                                A2B Veg         4   4.0
# 1               Amelie's Cafe & Creamery         1  22.0
# 2                   Bakya Veg Restaurant         1  23.0
# 3                        Cream and Fudge         2   8.0
# 4             Desi Rasoi's Punjabi Dhaba         1  24.0
# 5                         Domino's Pizza         4   5.0
# 6                         Drunken Monkey         1  25.0
# 7                                 Faasos         2   9.0
# 8                           Firangi Bake         1  26.0
# 9                         Food Centralis         1  27.0
# 10                            Food Track         5   3.0
# 11                         Frozen Bottle         2  10.0
# 12                          Good For One         1  28.0
# 13  HOTEL ANANDHA BHAVAN (Imperial Road)         2  11.0
# 14                                 Ibaco         1  29.0
# ...

# %%
# top rank
orders_new[orders_new['Rank']==1]
# Out:
#      restaurant_name  order_id  Rank
# 39  The Bowl Company        12   1.0

# %%
orders_new.sort_values(by=['order_id'],ascending = False)
# Out:
#                          restaurant_name  order_id  Rank
# 39                      The Bowl Company        12   1.0
# 22           Mansukh's Sweets and Snacks         6   2.0
# 10                            Food Track         5   3.0
# 0                                A2B Veg         4   4.0
# 44                             The Table         4   7.0
# 5                         Domino's Pizza         4   5.0
# 31                 Sangeetha's Desi Mane         4   6.0
# 20                              LunchBox         2  12.0
# 46                The Thickshake Factory         2  21.0
# 38                The Belgian Waffle Co.         2  20.0
# 36                             Taco Bell         2  19.0
# 34                                Subway         2  18.0
# 33                     Sree gupta bhavan         2  17.0
# 32            Shyam's Bombay Halwa House         2  16.0
# 29                             Roll Over         2  15.0
# ...

# %%
# change of revenue year to year
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               95 non-null     int64
#  1   order_id         95 non-null     int64
#  2   order_total      95 non-null     float64
#  3   restaurant_name  95 non-null     object
#  4   order_time       95 non-null     object
#  5   rain_mode        95 non-null     int64
#  6   on_time          95 non-null     int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 5.3+ KB

# %%
orders['order_time'] = orders['order_time'].apply(pd.to_datetime)
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               95 non-null     int64
#  1   order_id         95 non-null     int64
#  2   order_total      95 non-null     float64
#  3   restaurant_name  95 non-null     object
#  4   order_time       95 non-null     datetime64[ns]
#  5   rain_mode        95 non-null     int64
#  6   on_time          95 non-null     int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 5.3+ KB

# %%
orders['Year'] = orders['order_time'].dt.year
orders
# Out:
#     id      order_id  order_total          restaurant_name  \
# 0    1  127143465064        463.0                  A2B Veg
# 1    2  127077028490        252.0             Firangi Bake
# 2    3  126888939416        190.0                The Table
# 3    4  125668909627        258.0        Sree gupta bhavan
# 4    5  125301846779        194.0                   Idlies
# ..  ..           ...          ...                      ...
# 90  91    1161151700        313.0           Domino's Pizza
# 91  92    1129725726        192.0  The Thick Shake Factory
# 92  93    1123341565        125.0           Food Centralis
# 93  94    1123287736        209.0             Rice n Spice
# 94  95    1096353194        140.0        The Sandwich Shop
#
#             order_time  rain_mode  on_time  Year
# 0  2022-02-05 19:07:45          0        1  2022
# 1  2022-02-05 00:40:28          0        1  2022
# 2  2022-02-02 20:25:40          0        1  2022
# 3  2022-01-19 17:31:50          0        0  2022
# ...

# %%
# total revenue of years
orders2 = orders.groupby('Year')['order_total'].sum().reset_index()
orders2
# Out:
#    Year  order_total
# 0  2017        474.0
# 1  2018       3436.0
# 2  2019       7484.0
# 3  2020       3442.0
# 4  2021      11343.0
# 5  2022       1677.0

# %%
# comparing to previous year
orders2['previousYearSale']=orders2['order_total'].shift(1)
orders2
# Out:
#    Year  order_total  previousYearSale
# 0  2017        474.0               NaN
# 1  2018       3436.0             474.0
# 2  2019       7484.0            3436.0
# 3  2020       3442.0            7484.0
# 4  2021      11343.0            3442.0
# 5  2022       1677.0           11343.0

# %%
orders2['%diff']= (orders2['order_total']-orders2['previousYearSale'])/orders2['previousYearSale']
orders2
# Out:
#    Year  order_total  previousYearSale     %diff
# 0  2017        474.0               NaN       NaN
# 1  2018       3436.0             474.0  6.248945
# 2  2019       7484.0            3436.0  1.178114
# 3  2020       3442.0            7484.0 -0.540086
# 4  2021      11343.0            3442.0  2.295468
# 5  2022       1677.0           11343.0 -0.852156
